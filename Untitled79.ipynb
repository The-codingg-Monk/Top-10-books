# %%
import pandas as pd
import numpy as np

# %%
books=pd.read_csv(r"C:\Users\kannu\OneDrive\Desktop\Pandas_csvs\Datasets\Recommender_sys\book_recom\books.csv")
ratings=pd.read_csv(r"C:\Users\kannu\OneDrive\Desktop\Pandas_csvs\Datasets\Recommender_sys\book_recom\ratings.csv")
users=pd.read_csv(r"C:\Users\kannu\OneDrive\Desktop\Pandas_csvs\Datasets\Recommender_sys\book_recom\users.csv")
# Out:
# C:\Users\kannu\AppData\Local\Temp\ipykernel_9636\3447160075.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books=pd.read_csv(r"C:\Users\kannu\OneDrive\Desktop\Pandas_csvs\Datasets\Recommender_sys\book_recom\books.csv")

# %%
books
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
df=books.merge(ratings,on="ISBN")
df
# Out:
#                ISBN                                         Book-Title  \
# 0        0195153448                                Classical Mythology
# 1        0002005018                                       Clara Callan
# 2        0002005018                                       Clara Callan
# 3        0002005018                                       Clara Callan
# 4        0002005018                                       Clara Callan
# ...             ...                                                ...
# 1031131  0440400988                         There's a Bat in Bunk Five
# 1031132  0525447644                            From One to One Hundred
# 1031133  006008667X  Lily Dale : The True Story of the Town that Ta...
# 1031134  0192126040                        Republic (World's Classics)
# 1031135  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                   Book-Author Year-Of-Publication  \
# 0          Mark P. O. Morford                2002
# ...

# %%
book_rating=df.groupby("Book-Title").count()["Book-Rating"].reset_index()
avg_rating=df.groupby("Book-Title").mean()["Book-Rating"].reset_index()

# %%
df=book_rating.merge(avg_rating,on="Book-Title")

# %%
top_50_books=df.loc[df["Book-Rating_x"]>250].sort_values("Book-Rating_y",ascending=False).head(50).reset_index()

# %%
# top_50_books.drop("index",axis=1,inplace=True)
top_50_books=top_50_books.merge(books,on="Book-Title")[["Book-Title","Book-Author","Year-Of-Publication","Image-URL-M"]]

# %%
top_50_books.drop_duplicates("Book-Title",inplace=True)

# %%
top_50_books.reset_index(drop=True,inplace=True)

# %%
# top_50_books

# %%
data=(ratings.groupby("User-ID").count()["Book-Rating"]>200).reset_index()
ui=data.loc[data["Book-Rating"]==True]["User-ID"]

# %%
# ui_200=ratings[ratings["User-ID"].isin(ui)]
# ui_200

# %%
d1= ratings.groupby("User-ID").count()["Book-Rating"].reset_index()
ui_200=d1.loc[d1["Book-Rating"]>200]["User-ID"]
# books.loc[books["User-ID"].isin(ui_200)

# %%
ratings_with_name=books.merge(ratings,on="ISBN")

# %%
intel_users=ratings_with_name.groupby("User-ID").count()[ratings_with_name.groupby("User-ID").count()["Book-Rating"]>200].index

# %%
books_200_ui=ratings_with_name.loc[ratings_with_name["User-ID"].isin(intel_users)]

# %%
bokks_50=books_200_ui.groupby("Book-Title").count()[books_200_ui.groupby("Book-Title").count()["Book-Rating"]>=50].index

# %%
most_popular_books=books_200_ui.loc[books_200_ui["Book-Title"].isin(bokks_50)]

# %%
most_popular_books
# Out:
#                ISBN                       Book-Title      Book-Author  \
# 31       0399135782           The Kitchen God's Wife          Amy Tan
# 33       0399135782           The Kitchen God's Wife          Amy Tan
# 34       0399135782           The Kitchen God's Wife          Amy Tan
# 38       0399135782           The Kitchen God's Wife          Amy Tan
# 39       0399135782           The Kitchen God's Wife          Amy Tan
# ...             ...                              ...              ...
# 1028414  1878702831                           Echoes      Nancy Morse
# 1028600  0394429869  I Know Why the Caged Bird Sings     Maya Angelou
# 1028602  0449001164                      The Promise      CHAIM POTOK
# 1028815  0743527631         The Pillars of the Earth      Ken Follett
# 1028817  0745168086              The Handmaid's Tale  Margaret Atwood
#
#         Year-Of-Publication                      Publisher  \
# 31                     1991               Putnam Pub Group
# ...

# %%
pt=most_popular_books.pivot_table(index="Book-Title",columns='User-ID',values="Book-Rating")
pt.fillna(0,inplace=True)
pt.index[0]
# Out:
# '1984'

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cosine=cosine_similarity(pt)

# %%
def recommend(book):
    book_index=np.where(pt.index==book)[0][0]
    book_cosine=cosine[book_index]
    top_5=sorted(list(enumerate(book_cosine)),key=lambda x:x[1],reverse=True)[1:6]
    for ind in top_5:
        print(pt.index[ind[0]])

# %%
recommend('Harry Potter and the Prisoner of Azkaban (Book 3)')
# Out:
# Harry Potter and the Goblet of Fire (Book 4)
# Harry Potter and the Chamber of Secrets (Book 2)
# Harry Potter and the Order of the Phoenix (Book 5)
# Harry Potter and the Sorcerer's Stone (Book 1)
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))

# %%
print(books["Image-URL-M"][21])
# Out:
# http://images.amazon.com/images/P/1841721522.01.MZZZZZZZ.jpg

# %%
import pickle

with open(r"C:\Users\kannu\OneDrive\Desktop\DataScience\Projects\Book-recommender\popular_50_books.pkl","wb") as file:
    pickle.dump(top_50_books,file)

# %%
top_50_books.loc[0,:]
# Out:
# Book-Title             Harry Potter and the Prisoner of Azkaban (Book 3)
# Book-Author                                                J. K. Rowling
# Year-Of-Publication                                                 1999
# Image-URL-M            http://images.amazon.com/images/P/0439136350.0...
# Name: 0, dtype: object

# %%
top_50_books.merge
# Out:
#                                            Book-Title             Book-Author  \
# 0   Harry Potter and the Prisoner of Azkaban (Book 3)           J. K. Rowling
# 1        Harry Potter and the Goblet of Fire (Book 4)           J. K. Rowling
# 2      Harry Potter and the Sorcerer's Stone (Book 1)           J. K. Rowling
# 3   Harry Potter and the Order of the Phoenix (Boo...           J. K. Rowling
# 4    Harry Potter and the Chamber of Secrets (Book 2)           J. K. Rowling
# 5   The Hobbit : The Enchanting Prelude to The Lor...          J.R.R. TOLKIEN
# 6   The Fellowship of the Ring (The Lord of the Ri...          J.R.R. TOLKIEN
# 7   Harry Potter and the Sorcerer's Stone (Harry P...           J. K. Rowling
# 8      The Two Towers (The Lord of the Rings, Part 2)          J.R.R. TOLKIEN
# 9                               To Kill a Mockingbird              Harper Lee
# 10                                  The Da Vinci Code               Dan Brown
# ...
